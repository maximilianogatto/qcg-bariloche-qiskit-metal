# %% [markdown]
# # Impedance, admittance and scattering analysis
# ### Prerequisite
# You need to have a working local installation of Ansys.

# %%
# %load_ext autoreload
# %autoreload 2

import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings
import pyEPR as epr
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Create the design in Metal
# Set up a design of a given dimension. Dimensions will be respected in the design rendering. <br>
# Note that the design will be centered in the origin, will thus equally extend in all quadrants.

# %%
design = designs.DesignPlanar({}, True)
design.chips.main.size['size_x'] = '2mm'
design.chips.main.size['size_y'] = '2mm'

gui = MetalGUI(design)

# %% [markdown]
# Create a single transmon with one readout resonator. It will show in the center of the previously defined chip.

# %%
from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket

design.delete_all_components()

q1 = TransmonPocket(design, 'Q1', options =  dict(
    pad_width = '425 um', 
    pocket_height = '650um',
    connection_pads=dict(
        readout = dict(loc_W=+1,loc_H=+1, pad_width='200um')
    )))

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ## 2. Eigenmode and Impedance analysis using the analysis package - most users
#
# #### Setup
#
# Select the analysis you intend to run from the `qiskit_metal.analyses` collection.<br>
# Select the design to analyze and the tool to use for any external simulation.

# %%
from qiskit_metal.analyses.simulation import ScatteringImpedanceSim
em1 = ScatteringImpedanceSim(design, "hfss")

# %% [markdown]
# Review and update the setup. For driven modal you will need to define not only the simulation convergence parameters, but also the frequency sweep.
#
# Customizable parameters and default values:
# * freq_ghz=5 (simulation frequency)
# * name="Setup" (setup name)
# * max_delta_s=0.1 (absolute value of maximum difference in scattering parameter S)
# * max_passes=10 (maximum number of passes)
# * min_passes=1 (minimum number of passes)
# * min_converged=1 (minimum number of converged passes)
# * pct_refinement=30 (percent refinement)
# * basis_order=1 (basis order)
# * vars (global variables to set in the renderer)
# * sweep_setup (all the parameters of the sweep)
#  * name="Sweep" (name of sweep)
#  * start_ghz=2.0 (starting frequency)
#  * stop_ghz=8.0 (stopping frequency)
#  * count=101 (total number of frequencies)
#  * step_ghz=None (frequency step size)
#  * type="Fast" (type of sweep)
#  * save_fields=False (whether or not to save fields)
#
# The following two cells will give you an example on how to update the setup.

# %%
em1.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'freq_ghz': 5,
#  'max_delta_s': 0.1,
#  'max_passes': 10,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '10 nH', 'Cj': '0 fF'},
#  'sweep_setup': {'name': 'Sweep',
#   'start_ghz': 2.0,
#   'stop_ghz': 8.0,
#   'count': 101,
#   'step_ghz': None,
#   'type': 'Fast',
#   'save_fields': False}}

# %%
# example: update single setting
em1.setup.max_passes = 12
em1.setup.sweep_setup.stop_ghz = 13
# example: update multiple settings
em1.setup_update(max_delta_s = 0.15, freq_ghz = 5.2)

em1.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'freq_ghz': 5.2,
#  'max_delta_s': 0.15,
#  'max_passes': 12,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '10 nH', 'Cj': '0 fF'},
#  'sweep_setup': {'name': 'Sweep',
#   'start_ghz': 2.0,
#   'stop_ghz': 13,
#   'count': 101,
#   'step_ghz': None,
#   'type': 'Fast',
#   'save_fields': False}}

# %% [markdown]
# #### Execute simulation and observe the Impedence
# Analyze a single qubit with shorted terminations. Assign lumped ports on the readout and on the junction. Then observe the impedance plots.
#
# Here, pin Q1_a is converted into a lumped port with an impedance of 70 Ohms. <br>
# Meanwhile, the central junction Q1_rect_jj is rendered as both a port and an inductor with an impedance of 50 Ohms and an inductance of 10 nH, respectively.
#
# The 10nH inductance value is taken from the component option `hfss_inductance` (And the component options find their way in the QGeometry tables by rebuilding). So let's demonstrate how to update the inductance of the junction in the next cell.

# %%
q1.options.hfss_inductance='11nH'
gui.rebuild()

# %% [markdown]
# Now we can run the simulation with the newly set `11 nH` value.

# %%
em1.run(name="SingleTM", components=[], open_terminations=[], port_list=[('Q1', 'readout', 70)],
           jj_to_port=[('Q1', 'rect_jj', 50, True)], box_plus_buffer = False)
# Out:
# INFO 07:14PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 07:14PM [load_ansys_project]: 	Opened Ansys App
# INFO 07:14PM [load_ansys_project]: 	Opened Ansys Desktop v2024.2.1
# INFO 07:14PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Mac/Home/Documents/Ansoft/
# 	Project:   Project2
# INFO 07:14PM [connect_design]: 	Opened active design
# 	Design:    Scattering_hfss [Solution type: HFSS Hybrid Modal Network]
# ERROR 07:14PM [get_setup]: Could not retrieve setup: Setup
#                          Did you give the right name? Does it exist?
# ERROR 07:14PM [connect_setup]: Original error 😭: 'NoneType' object has no attribute 'name'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\maximilianogatto\.conda\envs\QDesign\Lib\site-packages\pyEPR\project_info.py:340, in ProjectInfo.connect_setup(self)
#     339     # get the actual setup if there is one
# --> 340     self.get_setup(self.setup_name)
#     342 except Exception as e:
#
# File c:\Users\maximilianogatto\.conda\envs\QDesign\Lib\site-packages\pyEPR\project_info.py:408, in ProjectInfo.get_setup(self, name)
#     405     logger.error(f"Could not retrieve setup: {name}\n \
#     406                 Did you give the right name? Does it exist?")
# --> 408 self.setup_name = self.setup.name
#     409 logger.info(
#     410     f'\tOpened setup `{self.setup_name}`  ({type(self.setup)})')
#
# AttributeError: 'NoneType' object has no attribute 'name'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 em1.run(name="SingleTM", components=[], open_terminations=[], port_list=[('Q1', 'readout', 70)],
#       2            jj_to_port=[('Q1', 'rect_jj', 50, True)], box_plus_buffer = False)
#
# File \\Mac\Balseiro\Tesis\src\libraries\qiskit_metal\qiskit_metal\analyses\core\simulation.py:203, in QSimulation.run(self, *args, **kwargs)
#     199 def run(self, *args, **kwargs):
#     200     """Alias for run_sim() necessary to implement super-class method, while
#     201     preventing method name collision when sim and non-sim QAnalysis classes are inherited.
#     202     """
# --> 203     self.run_sim(*args, **kwargs)
#
# File \\Mac\Balseiro\Tesis\src\libraries\qiskit_metal\qiskit_metal\analyses\simulation\scattering_impedance.py:172, in ScatteringImpedanceSim.run_sim(self, name, components, open_terminations, port_list, jj_to_port, ignored_jjs, box_plus_buffer)
#     169 self.clear_data()
#     171 if not self.renderer_initialized:
# --> 172     self._initialize_renderer()
#     174 vars_to_initialize = self.setup.vars
#     175 renderer_design_name = self._render(
#     176     name=name,
#     177     solution_type='drivenmodal',
#    (...)
#     183     box_plus_buffer=box_plus_buffer,
#     184     vars_to_initialize=vars_to_initialize)
#
# File \\Mac\Balseiro\Tesis\src\libraries\qiskit_metal\qiskit_metal\analyses\core\simulation.py:141, in QSimulation._initialize_renderer(self)
#     138 def _initialize_renderer(self):
#     139     """Starts the renderer by executing the routine of the selected renderer.
#     140     """
# --> 141     self.renderer.start()
#
# File \\Mac\Balseiro\Tesis\src\libraries\qiskit_metal\qiskit_metal\renderers\renderer_base\renderer_base.py:378, in QRenderer.start(self, force)
#     373         self._close_renderer()
#     375 # TODO: move the code line below to inside the `if force or not initiated`,
#     376 #  but only after the TODO before the `if` is completed
#     377 # try to initialize the renderer
# --> 378 self.initiated = self._initiate_renderer()
#     380 return self.initiated
#
# File \\Mac\Balseiro\Tesis\src\libraries\qiskit_metal\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:305, in QAnsysRenderer._initiate_renderer(self)
#     303 if self.rdesktop.project_count() == 0:
#     304     self.rdesktop.new_project()
# --> 305 self.connect_ansys()  # TODO: can this be done differently?
#     307 # return True to indicate successful completion
#     308 return True
#
# File \\Mac\Balseiro\Tesis\src\libraries\qiskit_metal\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:408, in QAnsysRenderer.connect_ansys(self, project_path, project_name, design_name)
#     405 import pythoncom
#     407 try:
# --> 408     self._pinfo = epr.ProjectInfo(
#     409         do_connect=True,
#     410         project_path=self._options["project_path"]
#     411         if not project_path else project_path,
#     412         project_name=self._options["project_name"]
#     413         if not project_name else project_name,
#     414         design_name=self._options['design_name']
#     415         if not design_name else design_name)
#     416 except pythoncom.com_error as error:  # pylint: disable=no-member
#     417     print("com_error: ", error)
#
# File c:\Users\maximilianogatto\.conda\envs\QDesign\Lib\site-packages\pyEPR\project_info.py:224, in ProjectInfo.__init__(self, project_path, project_name, design_name, setup_name, dielectrics_bulk, dielectric_surfaces, resistive_surfaces, seams, do_connect)
#     221 self.setup = None
#     223 if do_connect:
# --> 224     self.connect()
#     225     self.dissipative['pinfo'] = self
#
# File c:\Users\maximilianogatto\.conda\envs\QDesign\Lib\site-packages\pyEPR\project_info.py:365, in ProjectInfo.connect(self)
#     363 if self.project:
#     364     self.connect_design()
# --> 365 self.connect_setup()
#     367 # Finalize
#     368 if self.project:
#
# File c:\Users\maximilianogatto\.conda\envs\QDesign\Lib\site-packages\pyEPR\project_info.py:346, in ProjectInfo.connect_setup(self)
#     344         _traceback = sys.exc_info()[2]
#     345         logger.error(f"Original error \N{loudly crying face}: {e}\n")
# --> 346         raise Exception(' Did you provide the correct setup name?\
#     347                     Failed to pull up setup. \N{loudly crying face}'
#     348                         ).with_traceback(_traceback)
#     350 else:
#     351     self.setup = None
#
# File c:\Users\maximilianogatto\.conda\envs\QDesign\Lib\site-packages\pyEPR\project_info.py:340, in ProjectInfo.connect_setup(self)
#     337         self.setup_name = setup_names[0]
#     339     # get the actual setup if there is one
# --> 340     self.get_setup(self.setup_name)
#     342 except Exception as e:
#     344     _traceback = sys.exc_info()[2]
#
# File c:\Users\maximilianogatto\.conda\envs\QDesign\Lib\site-packages\pyEPR\project_info.py:408, in ProjectInfo.get_setup(self, name)
#     404 if self.setup is None:
#     405     logger.error(f"Could not retrieve setup: {name}\n \
#     406                 Did you give the right name? Does it exist?")
# --> 408 self.setup_name = self.setup.name
#     409 logger.info(
#     410     f'\tOpened setup `{self.setup_name}`  ({type(self.setup)})')
#     411 return self.setup
#
# Exception:  Did you provide the correct setup name?                            Failed to pull up setup. 😭

# %% [markdown]
# The last variables you pass to the `run()` or `run_sim()` methods, will be stored in the `setup` dictionary under the key `run`. You can recall the information passed by either accessing the dictionary directly, or by using the print handle below.

# %%
# em1.setup.run    <- direct access
em1.print_run_args()

# %% [markdown]
# (optional) Captures the renderer GUI.

# %%
em1.save_screenshot()

# %% [markdown]
# (optional) if you ever feel the need to remind yourself which project, design, and setup is currently active (connected to qiskit-metal) you can use the following lines.

# %%
print(f"""
project_name = {em1.renderer.pinfo.project_name}
design_name  = {em1.renderer.pinfo.design_name}
setup_name   = {em1.renderer.pinfo.setup_name}
""")

# %% [markdown]
# Finally, you can plot the various parameters. The semicolon at the end of the cell can be used to suppress the inline return.

# %%
em1.get_impedance();  # default: ['Z11', 'Z21']

# %%
em1.get_admittance();  # default: ['Y11', 'Y21']

# %%
em1.get_scattering();  # default: ['S11', 'S21', 'S22']

# %% [markdown]
# Finally, disconnect from Ansys.

# %%
em1.close()

# %% [markdown]
# ## 3. Directly access the renderer to modify other parameters

# %%
em1.start()
em1.renderer

# %% [markdown]
# Every renderer will have its own collection of methods. Below an example with hfss.

# %% [markdown]
# ##### Prepare and run a collection of predefined setups
#
# This is equivalent to going to the Project Manager panel in Ansys, right clicking on Analysis within the active HFSS design, selecting "Add Solution Setup...", and choosing/entering default values in the resulting popup window. You might want to do this to keep track of different solution setups, giving each of them a different/specific name.

# %%
setup = em1.renderer.new_ansys_setup(name = "Setup_demo", max_passes = 6)

# %% [markdown]
# You can directly pass to `new_ansys_setup` all the setup parameters. Of course you will then need to run the individual setups by name as well.

# %%
em1.renderer.analyze_setup(setup.name)

# %%
em1.close()
